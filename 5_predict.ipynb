# %%
from ultralytics import YOLO
from PIL import Image
# Out:
# C:\Users\User\anaconda3\envs\myenv_py_3_8_dl\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\User\anaconda3\envs\myenv_py_3_8_dl\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\User\anaconda3\envs\myenv_py_3_8_dl\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ### Картинки

# %%
model_path = 'runs/detect/yolov8n_ru_dataset_25/weights/best.pt'

image_path_1 = "archive/test/images/autosave01_02_2012_10_04_47.jpg"
image_path_2 = "archive/test/images/autosave01_02_2012_10_15_50.jpg"

# %%
model = YOLO(model_path)

# %%
results = model(image_path_1)

for r in results:
    im_array = r.plot()
    im = Image.fromarray(im_array[..., ::-1])
    im.save('results/example_image_1_predict_train_model.jpg')
# Out:
# image 1/1 C:\Users\User\Documents\Projects\itmo_deep_learning\archive\test\images\autosave01_02_2012_10_04_47.jpg: 384x640 1 Пешеходный переход, 1 Уступите дорогу, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
results = model(image_path_2)

for r in results:
    im_array = r.plot()
    im = Image.fromarray(im_array[..., ::-1])
    im.save('results/example_image_2_predict_train_model.jpg')
# Out:
# image 1/1 C:\Users\User\Documents\Projects\itmo_deep_learning\archive\test\images\autosave01_02_2012_10_15_50.jpg: 384x640 1 Дети, 2 Пешеходный переходs, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %% [markdown]
# ### Видео через predict

# %%
from IPython.display import Video

# %%
path_small_1 = 'example_video_small_1.mp4'
path_small_2 = 'example_video_small_2.mp4'
path_big = 'example_video_big.mp4'

# %%
# %%time

model_path = 'runs/detect/yolov8m_ru_dataset_25/weights/best.pt'
# !yolo task=detect mode=predict model=f'{model_path}' conf=0.5 source={path_small_1}
# Out:
# Ultralytics YOLOv8.0.215 рџљЂ Python-3.8.18 torch-2.1.1 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# Model summary (fused): 218 layers, 25929505 parameters, 0 gradients, 79.2 GFLOPs
#
# video 1/1 (1/458) C:\Users\User\Documents\Projects\itmo_deep_learning\example_video_small.mp4: 384x640 (no detections), 88.0ms
# video 1/1 (2/458) C:\Users\User\Documents\Projects\itmo_deep_learning\example_video_small.mp4: 384x640 (no detections), 6.0ms
# video 1/1 (3/458) C:\Users\User\Documents\Projects\itmo_deep_learning\example_video_small.mp4: 384x640 (no detections), 5.0ms
# video 1/1 (4/458) C:\Users\User\Documents\Projects\itmo_deep_learning\example_video_small.mp4: 384x640 (no detections), 6.0ms
# video 1/1 (5/458) C:\Users\User\Documents\Projects\itmo_deep_learning\example_video_small.mp4: 384x640 (no detections), 5.0ms
# video 1/1 (6/458) C:\Users\User\Documents\Projects\itmo_deep_learning\example_video_small.mp4: 384x640 (no detections), 5.0ms
# ...

# %%
# %%time

model_path = 'runs/detect/yolov8m_ru_dataset_25/weights/best.pt'
# !yolo task=detect mode=predict model=f'{model_path}' conf=0.5 source={path_small_2}
# Out:
# Ultralytics YOLOv8.0.215 рџљЂ Python-3.8.18 torch-2.1.1 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# Model summary (fused): 218 layers, 25929505 parameters, 0 gradients, 79.2 GFLOPs
#
# video 1/1 (1/368) C:\Users\User\Documents\Projects\itmo_deep_learning\example_video_small_2.mp4: 384x640 (no detections), 93.1ms
# video 1/1 (2/368) C:\Users\User\Documents\Projects\itmo_deep_learning\example_video_small_2.mp4: 384x640 (no detections), 5.0ms
# video 1/1 (3/368) C:\Users\User\Documents\Projects\itmo_deep_learning\example_video_small_2.mp4: 384x640 (no detections), 5.0ms
# video 1/1 (4/368) C:\Users\User\Documents\Projects\itmo_deep_learning\example_video_small_2.mp4: 384x640 (no detections), 5.0ms
# video 1/1 (5/368) C:\Users\User\Documents\Projects\itmo_deep_learning\example_video_small_2.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (6/368) C:\Users\User\Documents\Projects\itmo_deep_learning\example_video_small_2.mp4: 384x640 (no detections), 6.0ms
# ...

# %% [markdown]
# ### Видео по API

# %%
import requests

# %%
url = "http://127.0.0.1:8000/"

response = requests.get(url)
print(response.text)
# Out:
# {"message":"Hello World"}

# %%
add_path = 'runs/detect/predict/'

url = "http://127.0.0.1:8000/uploadfile/"

path_small = "example_video_small.mp4"

path_big = 'example_video_big.mp4'

# %%
# %%time
with open(path_small, "rb") as video_file:
    files = {"file": (video_file.name, video_file, "video/mp4")}
    response = requests.post(url, files=files)

print(response.text)
# Out:
# Internal Server Error
# CPU times: total: 15.6 ms
# Wall time: 138 ms

# %%
#Сохранение принятого файла
with open(f"results/{path_small}", "wb") as output_file:
    output_file.write(response.content)
