# %%
from ultralytics import YOLO
import torch
# Out:
# C:\Users\User\anaconda3\envs\myenv_py_3_8_dl\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\User\anaconda3\envs\myenv_py_3_8_dl\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\User\anaconda3\envs\myenv_py_3_8_dl\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
print(torch.cuda.is_available())
print(torch.cuda.current_device())
print(torch.cuda.get_device_name(torch.cuda.current_device()))

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')
# Out:
# True
# 0
# NVIDIA GeForce RTX 3090
# Using device: cuda

# %%
model = YOLO('yolov8n.pt')

# %%
model.tune(data='data_ru_translate.yaml', batch=32, epochs=25, iterations=5, optimizer='AdamW', plots=True, save=True, val=False)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs\detect\tune2'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/5 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune2\tune_scatter_plots.png
# Saved runs\detect\tune2\tune_fitness.png
#
# Tuner: 1/5 iterations complete ✅ (4000.45s)
# Tuner: Results saved to runs\detect\tune2
# Tuner: Best fitness=0.51812 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.73298, 'metrics/recall(B)': 0.62192, 'metrics/mAP50(B)': 0.70023, 'metrics/mAP50-95(B)': 0.49788, 'val/box_loss': 0.89145, 'val/cls_loss': 0.5784, 'val/dfl_loss': 0.82885, 'fitness': 0.51812}
# Tuner: Best fitness model is runs\detect\train3
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune2\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 2/5 with hyperparameters: {'lr0': 0.00884, 'lrf': 0.01, 'momentum': 0.96718, 'weight_decay': 0.00045, 'warmup_epochs': 2.66018, 'warmup_momentum': 0.63459, 'box': 7.5, 'cls': 0.53071, 'dfl': 1.5, 'hsv_h': 0.01355, 'hsv_s': 0.75248, 'hsv_v': 0.3923, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.55464, 'mosaic': 0.97431, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune2\tune_scatter_plots.png
# Saved runs\detect\tune2\tune_fitness.png
#
# Tuner: 2/5 iterations complete ✅ (7996.31s)
# Tuner: Results saved to runs\detect\tune2
# Tuner: Best fitness=0.51812 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.73298, 'metrics/recall(B)': 0.62192, 'metrics/mAP50(B)': 0.70023, 'metrics/mAP50-95(B)': 0.49788, 'val/box_loss': 0.89145, 'val/cls_loss': 0.5784, 'val/dfl_loss': 0.82885, 'fitness': 0.51812}
# Tuner: Best fitness model is runs\detect\train3
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune2\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 3/5 with hyperparameters: {'lr0': 0.00883, 'lrf': 0.00966, 'momentum': 0.94985, 'weight_decay': 0.00048, 'warmup_epochs': 2.87689, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.38228, 'dfl': 1.48616, 'hsv_h': 0.0195, 'hsv_s': 0.65197, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.10679, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.51528, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune2\tune_scatter_plots.png
# Saved runs\detect\tune2\tune_fitness.png
#
# Tuner: 3/5 iterations complete ✅ (12018.61s)
# Tuner: Results saved to runs\detect\tune2
# Tuner: Best fitness=0.51812 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.73298, 'metrics/recall(B)': 0.62192, 'metrics/mAP50(B)': 0.70023, 'metrics/mAP50-95(B)': 0.49788, 'val/box_loss': 0.89145, 'val/cls_loss': 0.5784, 'val/dfl_loss': 0.82885, 'fitness': 0.51812}
# Tuner: Best fitness model is runs\detect\train3
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune2\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 4/5 with hyperparameters: {'lr0': 0.0114, 'lrf': 0.01096, 'momentum': 0.90964, 'weight_decay': 0.00059, 'warmup_epochs': 3.19409, 'warmup_momentum': 0.64448, 'box': 8.12425, 'cls': 0.51823, 'dfl': 1.53966, 'hsv_h': 0.01177, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.11335, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 0.9183, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune2\tune_scatter_plots.png
# Saved runs\detect\tune2\tune_fitness.png
#
# Tuner: 4/5 iterations complete ✅ (16043.97s)
# Tuner: Results saved to runs\detect\tune2
# Tuner: Best fitness=0.51812 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.73298, 'metrics/recall(B)': 0.62192, 'metrics/mAP50(B)': 0.70023, 'metrics/mAP50-95(B)': 0.49788, 'val/box_loss': 0.89145, 'val/cls_loss': 0.5784, 'val/dfl_loss': 0.82885, 'fitness': 0.51812}
# Tuner: Best fitness model is runs\detect\train3
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune2\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 5/5 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.93108, 'weight_decay': 0.00051, 'warmup_epochs': 3.44226, 'warmup_momentum': 0.80984, 'box': 8.92121, 'cls': 0.5, 'dfl': 1.65818, 'hsv_h': 0.015, 'hsv_s': 0.87128, 'hsv_v': 0.39341, 'degrees': 0.0, 'translate': 0.08527, 'scale': 0.53191, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.57081, 'mosaic': 0.92556, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs\detect\tune2\tune_scatter_plots.png
# Saved runs\detect\tune2\tune_fitness.png
#
# Tuner: 5/5 iterations complete ✅ (20105.64s)
# Tuner: Results saved to runs\detect\tune2
# Tuner: Best fitness=0.51812 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.73298, 'metrics/recall(B)': 0.62192, 'metrics/mAP50(B)': 0.70023, 'metrics/mAP50-95(B)': 0.49788, 'val/box_loss': 0.89145, 'val/cls_loss': 0.5784, 'val/dfl_loss': 0.82885, 'fitness': 0.51812}
# Tuner: Best fitness model is runs\detect\train3
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs\detect\tune2\best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0

# %%
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
